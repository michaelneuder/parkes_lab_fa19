# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ell = int(1e6)
alpha = 0.4

# %%
x_1 = np.arange(0, 1.1, 0.1)
opt = [0.0007389879312515258, -0.00020335224150797195, -0.0005768535976611592, 
        0.001681784976014238, -0.0011780635099321573, -0.00042014244842529297, 
        0.0008580287580386587, -0.0002321039752860113, 0.0008791440286451952, 
        -0.0009563896484313511, -6.157220458984375e-05]
honest = [-0.1507891206665039, -0.13823347900132793, -0.12613002460037567, 
          -0.11167743469059278, -0.09368423223981648, -0.07323048657226562, 
          -0.05156956439302424, -0.026743419555303957, -0.005427821716232185, 
          -0.0007293896484295485, -0.0006185722045898437]

# %%
plt.style.use('fivethirtyeight')
f, ax = plt.subplots(figsize=(10,7))

ax.plot(x_1, opt, 'r--', alpha=0.5, label='optimal')
# ax.plot(x_1, opt_double, alpha=0.5, label='optimal-double act')
# ax.plot(x_1, opt_single, 'k', alpha=0.5, label='optimal-single')
# ax.plot(x_1, sm1, 'purple', linestyle='dashdot', alpha=0.5, label='sm1')

ax.plot(x_1, honest, 'k', alpha=0.5, label='honest')

ax.set_xticks(x_1)
ax.set_ylabel(r'reward per block mined')
ax.set_xlabel(r'$C-$cost of mining')
ax.set_title(r'$\alpha=0.4$')
plt.legend(frameon=True, facecolor='white', framealpha=1)
f.set_facecolor('white')
# ax.set_xlim([0.5,0.9])
# ax.set_ylim(0.0, 0.1)
plt.show()

# %%
alpha*(1-.9)/2
# Out:
# 0.019999999999999997
