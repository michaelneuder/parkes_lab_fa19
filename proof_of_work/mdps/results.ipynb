# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [0.05, 0.10, 0.15, .2, .4]
y = [.05240, 0.10979, 0.17181, 0.23799, .61]

# %%
[
0.05 , 0.05240 , 0.05272,
0.10 , 0.10979 , 0.11011,
0.15 , 0.17181 , 0.17214, 
0.20 , 0.23799 , 0.23832,
0.25 , 0.30759 , 0.30791,
0.30 , 0.37965 , 0.37996,
0.35 , 0.47539 , 0.47558,
0.40 , 0.61418 , 0.61795,
0.45 , 0.78529 , 0.93585
][2::3]
# Out:
# [0.05272,
#  0.11011,
#  0.17214,
#  0.23832,
#  0.30791,
#  0.37996,
#  0.47558,
#  0.61795,
#  0.93585]

# %%
x = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45]
lbs = [0.0524, 0.10979, 0.17181, 0.23799, 0.30759, 0.37965, 0.47539, 0.61418, 0.78529]
ubs = [0.05272, 0.11011, 0.17214, 0.23832, 0.30791, 0.37996, 0.47558, 0.61795, 0.93585]

# %%
f, ax = plt.subplots(figsize=(8,8))
ax.plot(np.linspace(0.05, 0.45, 9),np.linspace(0.05, 0.45, 9), 'k--', alpha=0.4, label='honest mining')
ax.scatter(x, ubs, marker='o', c='g',s=100, alpha=0.2, label='upper bound')
ax.plot(x, lbs, 'x', c='r', label='eps-OPT policy')
ax.set_xticks(np.linspace(0.00, 0.5, 11))
ax.set_yticks(np.linspace(0.00, 1, 11))
ax.set_xlabel(r"$\alpha$")
ax.set_ylabel(r"$\rho$ (revenue)")
plt.legend()
plt.savefig('opt_results_1.png')
plt.show()

# %%
# matlab
results = np.asarray([[0.025, 0.02500152587890625, 0.02501373291015625],
 [0.05, 0.04999542236328125, 0.05000762939453125],
 [0.075, 0.07500457763671875, 0.07501678466796875],
 [0.1, 0.09999847412109375, 0.10001068115234375],
 [0.125, 0.12499237060546875, 0.12500457763671874],
 [0.15, 0.15000152587890625, 0.15001373291015624],
 [0.175, 0.17499542236328125, 0.17500762939453124],
 [0.19999999999999998, 0.20000457763671875, 0.20001678466796874],
 [0.22499999999999998, 0.22499847412109375, 0.22501068115234374],
 [0.24999999999999997, 0.24999237060546875, 0.25000457763671874],
 [0.27499999999999997, 0.27500152587890625, 0.27501373291015624],
 [0.3, 0.29999542236328125, 0.30000762939453124],
 [0.325, 0.32500457763671875, 0.32501678466796874],
 [0.35, 0.36988067626953125, 0.37042999267578125],
 [0.375, 0.42377471923828125, 0.42766876220703126],
 [0.39999999999999997, 0.48328399658203125, 0.5311233520507812],
 [0.425, 0.5529556274414062, 0.6529434204101563],
 [0.45, 0.6354598999023438, 0.7354476928710938],
 [0.475, 0.7264022827148438, 0.8263900756835938]])

# %%
x = results[:,0]
lbs = results[:,1]
ubs = results[:,2]

# %%
f, ax = plt.subplots(figsize=(8,8))
ax.plot(x,x, 'k--', alpha=0.4, label='honest mining')
ax.scatter(x, ubs, marker='o', c='g',s=100, alpha=0.2, label='upper bound')
ax.plot(x, lbs, 'x', c='r', label='eps-OPT policy')
ax.set_xticks(np.linspace(0.00, 0.5, 11))
ax.set_yticks(np.linspace(0.00, 1, 11))
ax.set_xlabel(r"$\alpha$")
ax.set_ylabel(r"$\rho$ (revenue)")
plt.legend()
plt.savefig('opt_results_2.png')
plt.show()

# %%
results = np.asarray(
[[0.025, 0.02500152587890625, 0.02501373291015625],
 [0.05, 0.04999542236328125, 0.05000762939453125],
 [0.075, 0.07500457763671875, 0.07501678466796875],
 [0.1, 0.09999847412109375, 0.10001068115234375],
 [0.125, 0.12499237060546875, 0.12500457763671874],
 [0.15, 0.15000152587890625, 0.15001373291015624],
 [0.175, 0.17499542236328125, 0.17500762939453124],
 [0.19999999999999998, 0.20000457763671875, 0.20001678466796874],
 [0.22499999999999998, 0.22499847412109375, 0.22501068115234374],
 [0.24999999999999997, 0.24999237060546875, 0.25000457763671874],
 [0.27499999999999997, 0.27500152587890625, 0.27501373291015624],
 [0.3, 0.29999542236328125, 0.30000762939453124],
 [0.325, 0.32500457763671875, 0.32501678466796874],
 [0.35, 0.37061309814453125, 0.37062530517578124],
 [0.375, 0.42548370361328125, 0.42559356689453126],
 [0.39999999999999997, 0.48706817626953125, 0.4878860473632813],
 [0.425, 0.5626449584960938, 0.6043807983398437],
 [0.45, 0.6545486450195312, 0.7545364379882813],
 [0.475, 0.7626266479492188, 0.8626144409179688]]
)
x = results[:,0]
lbs = results[:,1]
ubs = results[:,2]

# %%
f, ax = plt.subplots(figsize=(8,8))
ax.plot(x,x, 'k--', alpha=0.4, label='honest mining')
ax.scatter(x, ubs, marker='o', c='g',s=100, alpha=0.2, label='upper bound')
ax.plot(x, lbs, 'x', c='r', label='eps-OPT policy')
ax.set_xticks(np.linspace(0.00, 0.5, 11))
ax.set_yticks(np.linspace(0.00, 1, 11))
ax.set_xlabel(r"$\alpha$")
ax.set_ylabel(r"$\rho$ (revenue)")
plt.legend(loc=2)
plt.savefig('opt_results_3.png')
plt.show()

# %%
results = np.asarray(
[[0.025, 0.02564239501953125, 0.02565460205078125],
 [0.05, 0.05263519287109375, 0.05264739990234375],
 [0.075, 0.08107757568359375, 0.08108978271484375],
 [0.1, 0.11110687255859375, 0.11111907958984375],
 [0.125, 0.14286041259765625, 0.14287261962890624],
 [0.15, 0.17647552490234375, 0.17648773193359374],
 [0.175, 0.21212005615234375, 0.21213226318359374],
 [0.19999999999999998, 0.24999237060546875, 0.25000457763671874],
 [0.22499999999999998, 0.29032135009765625, 0.29033355712890624],
 [0.24999999999999997, 0.33333587646484375, 0.33334808349609374],
 [0.27499999999999997, 0.37931060791015625, 0.37932281494140624],
 [0.3, 0.42856597900390625, 0.42857818603515624],
 [0.325, 0.48148345947265625, 0.48149566650390624],
 [0.35, 0.5384597778320312, 0.5384719848632813],
 [0.375, 0.5999984741210938, 0.6000106811523438],
 [0.39999999999999997, 0.6666488647460938, 0.6666610717773438],
 [0.425, 0.7390060424804688, 0.7390182495117188],
 [0.45, 0.8170394897460938, 0.9170272827148438],
 [0.475, 0.8965377807617188, 0.9965255737304688]]
)
x = results[:,0]
lbs = results[:,1]
ubs = results[:,2]

# %%
f, ax = plt.subplots(figsize=(8,8))
ax.plot(x,x, 'k--', alpha=0.4, label='honest mining')
ax.scatter(x, ubs, marker='o', c='g',s=100, alpha=0.2, label='upper bound')
ax.plot(x, lbs, 'x', c='r', label='eps-OPT policy')
ax.plot(x, x/(1-x), 'y--', alpha=0.5)
ax.set_xticks(np.linspace(0.00, 0.5, 11))
ax.set_yticks(np.linspace(0.00, 1, 11))
ax.set_xlabel(r"$\alpha$")
ax.set_ylabel(r"$\rho$ (revenue)")
plt.legend(loc=2)
plt.savefig('opt_results_4.png')
plt.show()

# %%
results = np.asarray(
[[0.3, 0.29999542236328125, 0.30000762939453124],
 [0.35, 0.37076568603515625, 0.37077789306640624],
 [0.4, 0.48863983154296875, 0.48865203857421874],
 [0.45, 0.6681442260742188, 0.6705490112304688]]
)
x = results[:,0]
lbs = results[:,1]
ubs = results[:,2]

# %%
f, ax = plt.subplots(figsize=(8,8))
ax.plot(x,x, 'k--', alpha=0.4, label='honest mining')
ax.scatter(x, ubs, marker='o', c='g',s=100, alpha=0.2, label='upper bound')
ax.plot(x, lbs, 'x', c='r', label='eps-OPT policy')
ax.plot(x, x/(1-x), 'y--', alpha=0.5)
ax.set_xticks(np.linspace(0.00, 0.5, 11))
ax.set_yticks(np.linspace(0.00, 1, 11))
ax.set_xlabel(r"$\alpha$")
ax.set_ylabel(r"$\rho$ (revenue)")
plt.legend(loc=2)
plt.savefig('opt_results_5.png')
plt.show()

# %%
results = np.asarray(
[[0.3, 0.42856597900390625, 0.42857818603515624],
 [0.35, 0.5384597778320312, 0.5384719848632813],
 [0.4, 0.6666641235351562, 0.6666763305664063],
 [0.45, 0.8181686401367188, 0.8181808471679688]]
)
x = results[:,0]
lbs = results[:,1]
ubs = results[:,2]

# %%
f, ax = plt.subplots(figsize=(8,8))
ax.plot(x,x, 'k--', alpha=0.4, label='honest mining')
ax.scatter(x, ubs, marker='o', c='g',s=100, alpha=0.2, label='upper bound')
ax.plot(x, lbs, 'x', c='r', label='eps-OPT policy')
ax.plot(x, x/(1-x), 'y--', alpha=0.5)
ax.set_xticks(np.linspace(0.00, 0.5, 11))
ax.set_yticks(np.linspace(0.00, 1, 11))
ax.set_xlabel(r"$\alpha$")
ax.set_ylabel(r"$\rho$ (revenue)")
plt.legend(loc=2)
plt.savefig('opt_results_6.png')
plt.show()
